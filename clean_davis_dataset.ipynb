# %%
import pandas as pd

# %%
davis_data = pd.read_csv("CPM-matrix_Tony.xlsx")
head(davis_data)

# %%
# need to clean the data, swtich cols and rows, remove the _count columns
# maybe rename hSR6 to control? or rename to be a little more clear
# this clean dataset will be called ...

# %%
# do PCA analysis
