# %%
import pandas as pd

data = pd.read_parquet("data/sample_by_gene.parquet")

# %%
data.head()
# Out:
# gene_id sample_type  ENSG00000000003  ENSG00000000005  ENSG00000000419  \
# sample
# None           ZDS2         7.084306         0.104181        53.270856
# None           SP1R         6.905406         0.000000        54.658290
# None           SP1R         6.854844         0.000000        49.959774
# None          nZF36         5.948875         0.000000        56.318380
# None          nZF36         7.740376         0.000000        53.638417
#
# gene_id  ENSG00000000457  ENSG00000000460  ENSG00000000938  ENSG00000000971  \
# sample
# None            5.834134        10.626459              0.0         0.104181
# None            5.393228        10.060444              0.0         0.103716
# None            4.909551         9.263303              0.0         0.046317
# None            4.332183        10.141247              0.0         0.000000
# None            4.894016         8.221947              0.0         0.097880
#
# ...

# %%
data['sample_type'].nunique()
# Out:
# 22
