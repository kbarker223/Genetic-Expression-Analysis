# %%
import pandas as pd

data = pd.read_parquet("data/sample_by_gene.parquet")

# %%
raw = pd.read_excel("data/CPM-matrix_Tony.xlsx")

# %%
data.head()
# Out:
# gene_id      sample_type  ENSG00000000003  ENSG00000000005  ENSG00000000419  \
# sample
# ZDS2_1_2_cpm        ZDS2         7.084306         0.104181        53.270856
# SP1R_1_cpm          SP1R         6.905406         0.000000        54.658290
# SP1R_2_cpm          SP1R         6.854844         0.000000        49.959774
# nZF36_1_cpm        nZF36         5.948875         0.000000        56.318380
# nZF36_2_cpm        nZF36         7.740376         0.000000        53.638417
#
# gene_id       ENSG00000000457  ENSG00000000460  ENSG00000000938  \
# sample
# ZDS2_1_2_cpm         5.834134        10.626459              0.0
# SP1R_1_cpm           5.393228        10.060444              0.0
# SP1R_2_cpm           4.909551         9.263303              0.0
# nZF36_1_cpm          4.332183        10.141247              0.0
# nZF36_2_cpm          4.894016         8.221947              0.0
#
# gene_id       ENSG00000000971  ENSG00000001036  ENSG00000001084  ...  \
# ...

# %%
print(f"{data['sample_type'].nunique()} unique treatment types including control")
print(f"{len(data.columns)} genes available")
print(f"{len(raw['gene_biotype'].unique())} unique gene biotypes including {raw['gene_biotype'].unique()[:3].tolist()}")
# Out:
# 22 unique treatment types including control
# 78987 genes available
# 39 unique gene biotypes including ['protein_coding', 'transcribed_unprocessed_pseudogene', 'processed_pseudogene']
